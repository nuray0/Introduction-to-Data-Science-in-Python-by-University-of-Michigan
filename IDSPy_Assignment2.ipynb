# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from io import StringIO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
url = "https://qmkhzwty.labs.coursera.org/files/assignments/assignment2/assets/NISPUF17.csv"
r = requests.get(url).content
df = pd.read_csv(StringIO(r))
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-2de961c78e7e> in <module>()
#       2 url = "https://qmkhzwty.labs.coursera.org/files/assignments/assignment2/assets/NISPUF17.csv"
#       3 r = requests.get(url).content
# ----> 4 df = pd.read_csv(StringIO(r))
#       5 df.head()
#
# TypeError: initial_value must be str or None, not bytes
